# %%
import torch
import torch.nn as nn
import torch.optim as optim

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(777)

# %%
# 단층 퍼셉트론 구현하기
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]]).to(device)
Y = torch.FloatTensor([[0], [1], [1], [0]]).to(device)

# %%
linear = nn.Linear(2, 1, bias=True)
sigmoid = nn.Sigmoid()
model1 = nn.Sequential(linear, sigmoid).to(device)

# %%
# nn.BCELoss(): 크로스 엔트로피 함수
criterion = nn.BCELoss().to(device)
optimizer = optim.SGD(model1.parameters(), lr=1)

# %%
for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model1(X)

    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 100 == 0: # 100번째 에포크마다 비용 출력
        print(step, cost.item())
# Out:
# 0 0.7666423320770264
# 100 0.6931473612785339
# 200 0.6931471824645996
# 300 0.6931471824645996
# 400 0.6931471824645996
# 500 0.6931471824645996
# 600 0.6931471824645996
# 700 0.6931471824645996
# 800 0.6931471824645996
# 900 0.6931471824645996
# 1000 0.6931471824645996
# 1100 0.6931471824645996
# 1200 0.6931471824645996
# 1300 0.6931471824645996
# 1400 0.6931471824645996
# 1500 0.6931471824645996
# 1600 0.6931471824645996
# 1700 0.6931471824645996
# 1800 0.6931471824645996
# 1900 0.6931471824645996
# 2000 0.6931471824645996
# 2100 0.6931471824645996
# 2200 0.6931471824645996
# 2300 0.6931471824645996
# 2400 0.6931471824645996
# 2500 0.6931471824645996
# 2600 0.6931471824645996
# 2700 0.6931471824645996
# 2800 0.6931471824645996
# 2900 0.6931471824645996
# 3000 0.6931471824645996
# 3100 0.6931471824645996
# 3200 0.6931471824645996
# 3300 0.6931471824645996
# 3400 0.6931471824645996
# 3500 0.6931471824645996
# 3600 0.6931471824645996
# 3700 0.6931471824645996
# 3800 0.6931471824645996
# 3900 0.6931471824645996
# 4000 0.6931471824645996
# 4100 0.6931471824645996
# 4200 0.6931471824645996
# 4300 0.6931471824645996
# 4400 0.6931471824645996
# 4500 0.6931471824645996
# 4600 0.6931471824645996
# 4700 0.6931471824645996
# 4800 0.6931471824645996
# 4900 0.6931471824645996
# 5000 0.6931471824645996
# 5100 0.6931471824645996
# 5200 0.6931471824645996
# 5300 0.6931471824645996
# 5400 0.6931471824645996
# 5500 0.6931471824645996
# 5600 0.6931471824645996
# 5700 0.6931471824645996
# 5800 0.6931471824645996
# 5900 0.6931471824645996
# 6000 0.6931471824645996
# 6100 0.6931471824645996
# 6200 0.6931471824645996
# 6300 0.6931471824645996
# 6400 0.6931471824645996
# 6500 0.6931471824645996
# 6600 0.6931471824645996
# 6700 0.6931471824645996
# 6800 0.6931471824645996
# 6900 0.6931471824645996
# 7000 0.6931471824645996
# 7100 0.6931471824645996
# 7200 0.6931471824645996
# 7300 0.6931471824645996
# 7400 0.6931471824645996
# 7500 0.6931471824645996
# 7600 0.6931471824645996
# 7700 0.6931471824645996
# 7800 0.6931471824645996
# 7900 0.6931471824645996
# 8000 0.6931471824645996
# 8100 0.6931471824645996
# 8200 0.6931471824645996
# 8300 0.6931471824645996
# 8400 0.6931471824645996
# 8500 0.6931471824645996
# 8600 0.6931471824645996
# 8700 0.6931471824645996
# 8800 0.6931471824645996
# 8900 0.6931471824645996
# 9000 0.6931471824645996
# 9100 0.6931471824645996
# 9200 0.6931471824645996
# 9300 0.6931471824645996
# 9400 0.6931471824645996
# 9500 0.6931471824645996
# 9600 0.6931471824645996
# 9700 0.6931471824645996
# 9800 0.6931471824645996
# 9900 0.6931471824645996
# 10000 0.6931471824645996

# %%
with torch.no_grad():
    hypothesis = model1(X)
    predicted = (hypothesis > 0.5).float()
    accuracy = (predicted == Y).float().mean()
    print('모델의 출력값(Hypothesis): ', hypothesis.detach().cpu().numpy())
    print('모델의 예측값(Predicted): ', predicted.detach().cpu().numpy())
    print('실제값(Y): ', Y.cpu().numpy())
    print('정확도(Accuracy): ', accuracy.item())
# Out:
# 모델의 출력값(Hypothesis):  [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
# 모델의 예측값(Predicted):  [[0.]
#  [0.]
#  [0.]
#  [0.]]
# 실제값(Y):  [[0.]
#  [1.]
#  [1.]
#  [0.]]
# 정확도(Accuracy):  0.5

# %%
# 다충 퍼셉트론 구현하기
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]]).to(device)
Y = torch.FloatTensor([[0], [1], [1], [0]]).to(device)

# %%
model2 = nn.Sequential(
    nn.Linear(2, 10, bias=True),
    nn.Sigmoid(),
    nn.Linear(10, 10, bias=True),
    nn.Sigmoid(),
    nn.Linear(10, 10, bias=True),
    nn.Sigmoid(),
    nn.Linear(10, 1, bias=True),
    nn.Sigmoid(),
).to(device)

# %%
criterion = nn.BCELoss().to(device)
optimizer = optim.SGD(model2.parameters(), lr=1)

# %%
for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model2(X)

    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 100 == 0:
        print(step, cost.item())
# Out:
# 0 0.6935927867889404
# 100 0.6931597590446472
# 200 0.693156361579895
# 300 0.6931530237197876
# 400 0.6931496858596802
# 500 0.6931464672088623
# 600 0.6931431293487549
# 700 0.6931397914886475
# 800 0.6931362748146057
# 900 0.6931326389312744
# 1000 0.6931289434432983
# 1100 0.6931248903274536
# 1200 0.6931205987930298
# 1300 0.6931159496307373
# 1400 0.6931108236312866
# 1500 0.6931053996086121
# 1600 0.6930992007255554
# 1700 0.6930922865867615
# 1800 0.6930845975875854
# 1900 0.6930757164955139
# 2000 0.6930655241012573
# 2100 0.6930536031723022
# 2200 0.6930396556854248
# 2300 0.6930230855941772
# 2400 0.6930030584335327
# 2500 0.69297856092453
# 2600 0.6929478645324707
# 2700 0.6929088830947876
# 2800 0.6928580403327942
# 2900 0.6927897930145264
# 3000 0.6926950812339783
# 3100 0.6925574541091919
# 3200 0.6923462152481079
# 3300 0.6919959187507629
# 3400 0.6913490295410156
# 3500 0.6899409294128418
# 3600 0.6858916282653809
# 3700 0.6661878824234009
# 3800 0.5242013931274414
# 3900 0.03667004033923149
# 4000 0.00951751135289669
# 4100 0.005071739200502634
# 4200 0.0033782669343054295
# 4300 0.0025058125611394644
# 4400 0.001979584340006113
# 4500 0.001629887381568551
# 4600 0.0013816446298733354
# 4700 0.0011968070175498724
# 4800 0.0010541375959292054
# 4900 0.0009408602491021156
# 5000 0.00084882159717381
# 5100 0.0007726647891104221
# 5200 0.0007086119148880243
# 5300 0.0006540918257087469
# 5400 0.0006071003153920174
# 5500 0.0005662246840074658
# 5600 0.0005303050274960697
# 5700 0.0004986046114936471
# 5800 0.0004703181912191212
# 5900 0.0004449697444215417
# 6000 0.000422150653321296
# 6100 0.00040149319102056324
# 6200 0.0003826850443147123
# 6300 0.0003655389591585845
# 6400 0.0003497969009913504
# 6500 0.00033530767541378736
# 6600 0.0003219969803467393
# 6700 0.0003096437139902264
# 6800 0.00029815983725711703
# 6900 0.00028746697353199124
# 7000 0.0002775223692879081
# 7100 0.00026819942286238074
# 7200 0.00025949531118385494
# 7300 0.00025126110995188355
# 7400 0.0002435907954350114
# 7500 0.00023634232638869435
# 7600 0.00022946600802242756
# 7700 0.00022300229466054589
# 7800 0.00021687723346985877
# 7900 0.00021107470092829317
# 8000 0.0002055525837931782
# 8100 0.00020029896404594183
# 8200 0.0001953031460288912
# 8300 0.00019057108147535473
# 8400 0.00018605057266540825
# 8500 0.00018171522242482752
# 8600 0.00017757367459125817
# 8700 0.00017361814389005303
# 8800 0.00016984381363727152
# 8900 0.0001661854621488601
# 9000 0.00016272689390461892
# 9100 0.00015937467105686665
# 9200 0.00015615321171935648
# 9300 0.0001530592271592468
# 9400 0.00015011835785117
# 9500 0.00014723723870702088
# 9600 0.00014447406283579767
# 9700 0.00014182314043864608
# 9800 0.00013925388338975608
# 9900 0.00013676268281415105
# 10000 0.0001343775074928999

# %%
with torch.no_grad():
    hypothesis = model(X)
    predicted = (hypothesis > 0.5).float()
    accuracy = (predicted == Y).float().mean()
    print('모델의 출력값(Hypothesis): ', hypothesis.detach().cpu().numpy())
    print('모델의 예측값(Predicted): ', predicted.detach().cpu().numpy())
    print('실제값(Y): ', Y.cpu().numpy())
    print('정확도(Accuracy): ', accuracy.item())
# Out:
# 모델의 출력값(Hypothesis):  [[0.4206124 ]
#  [0.4206282 ]
#  [0.4205934 ]
#  [0.42062336]]
# 모델의 예측값(Predicted):  [[0.]
#  [0.]
#  [0.]
#  [0.]]
# 실제값(Y):  [[0.]
#  [1.]
#  [1.]
#  [0.]]
# 정확도(Accuracy):  0.5
